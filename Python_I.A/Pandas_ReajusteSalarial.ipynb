# %%
import pandas as pd

funcionarios_df = pd.read_csv('CadastroFuncionarios.csv', sep=';', decimal=',')
clientes_df = pd.read_csv('CadastroClientes.csv', sep=';', decimal=',')
servicos_df = pd.read_excel('BaseServiçosPrestados.xlsx')

funcionarios_df = funcionarios_df.drop(['Estado Civil', 'Cargo'], axis=1)
display(funcionarios_df)
display(clientes_df)
display(servicos_df)
# Out:
#      ID Funcionário           Nome Completo  Salario Base  Impostos  \
# 0                 1        Gabriel Mesquita         21910   10955.0
# 1                 2             João Haddad          5404    2702.0
# 2                 3  Amanda Marques Ribeiro         16066    8033.0
# 3                 4         Guilherme Nunez         21305   10652.5
# 4                 5           Adelino Gomes          5098    2549.0
# ..              ...                     ...           ...       ...
# 109             143   Renan Scharnhorst Ott         10793    5396.5
# 110             144      Lucas Brum Pereira          4048    2024.0
# 111             148            Caio Stellet         24596   12298.0
# 112             149          Fernanda Rocha          5078    2539.0
# 113             150            Eduardo Brum         15939    7969.5
#
#      Beneficios   VT      VR            Area
# 0        4382.0  242  719.04       Operações
# 1        1080.8  154  574.56       Logística
# ...

# %%
folha = sum(funcionarios_df['Salario Base']) + sum(funcionarios_df['Impostos']) + sum(funcionarios_df['Beneficios'])

print(f'                FOLHA TOTAL = R$ {folha + (folha*0.10):,}') 
print('#'*64)
for i, nome in enumerate(funcionarios_df['Nome Completo']):
    a = funcionarios_df.loc[i, 'Salario Base']
    b = funcionarios_df.loc[i, 'Impostos']
    c = funcionarios_df.loc[i, 'Beneficios']
    d = (a + b + c)
    print('{:<50} = R$ {:,}'.format(nome, d + d * 0.10 ))
    
    
total_salario = sum(funcionarios_df['Salario Base'])
print('#'*64)
print(f'                SALARIO TOTAL = R$ {total_salario + (total_salario * 0.10):,}')
# Out:
#                 FOLHA TOTAL = R$ 2,875,777.63
# ################################################################
# Gabriel Mesquita                                   = R$ 40,971.7
# João Haddad                                        = R$ 10,105.48
# Amanda Marques Ribeiro                             = R$ 30,043.420000000002
# Guilherme Nunez                                    = R$ 39,840.35
# Adelino Gomes                                      = R$ 9,533.26
# Audir de Avila Goulart                             = R$ 44,296.56
# Zilma Guimarães                                    = R$ 33,426.25
# Gil Bonder                                         = R$ 6,619.8
# Gustavo de Melo Teixeira                           = R$ 43,967.44
# Andre Campos                                       = R$ 46,482.590000000004
# André Melo Soledade                                = R$ 18,615.85
# Luca Costa                                         = R$ 42,972.6
# ...
